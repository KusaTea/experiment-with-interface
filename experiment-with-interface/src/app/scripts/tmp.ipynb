# %%
import json

# %%
rus = {
    'main_window': {
        'new_record_button': 'НОВАЯ ЗАПИСЬ',
        'settings_button': 'НАСТРОЙКИ',
    },
    'connection_window': {
        'connect_button': 'подключиться к устройствам',
        'myograph_label': 'электромиограф:',
        'glove_label': 'перчатка:',
        'back_button': 'назад',
        'start_record_button': 'начать запись',
        'connected': 'подключено',
        'not_connected': 'нет подключения' ,
    },
    'experiment_controller': {
        'rest': 'ОТДЫХ',
        'calibration': 'КАЛИБРОВКА',
        'exercise': 'УПРАЖНЕНИЕ'
    },
    'finish_window': {
        'experiment_finish_label': 'эксперимент окончен',
        'thanks_labels': 'СПАСИБО ЗА УЧАСТИЕ!',
        'save_directory_label': 'сохраненный файл:\n',
        'main_menu_button': 'главное меню'
    },
    'participant_window': {
        'field_hint': 'введите число...',
        'code_field': 'код испытуемого',
        'age_field': 'возраст',
        'gender_radio': 'пол',
        'hand_radio': 'ведущая рука',
        'back_button': 'назад',
        'next_button': 'далее'
    },
    'settings_window': {
        'experiment_tab': 'Эксперимент',
        'glove_tab': 'Перчатка',
        'myograph_tab': 'Миограф',
        'back_button': 'назад',
        'save_button': 'сохранить',
        'text_field_hint': 'Введите текст...',
        'number_field_hint': 'Введите число...',
        'save_data_dir_field': 'Директория для сохранения данных',
        'number_of_exercise_repeats_field': 'Количество повторов упражнений',
        'exercise_time_field': 'Длительность выполнения упражнения (с)',
        'rest_time_field': 'Длительность отдыха (с)',
        'ip_address_field': 'Ip-адрес',
        'port_field': 'Порт',
        'high_pass_filter': 'Фильтр высоких частот',
        'low_pass_filter': 'Фильтр низких частот',
        'detection_mode': 'Тип отведения',
        'electrodes_type': 'Вид электродов',
        'adapter_type': 'Вид адаптера',
        'sampling_rate': 'Частота дискретизации (Гц)',
        'active_in_channels': 'Активные каналы записи'
    }
}

# %%
eng = {
    'main_window': {
        'new_record_button': 'NEW RECORD',
        'settings_button': 'SETTINGS',
    },
    'connection_window': {
        'connect_button': 'connect to devices',
        'myograph_label': 'myograph:',
        'glove_label': 'glove:',
        'back_button': 'back',
        'start_record_button': 'start record',
        'connected': 'connected',
        'not_connected': 'not connected' ,
    },
    'experiment_controller': {
        'rest': 'REST',
        'calibration': 'CALIBRATION',
        'exercise': 'EXERCISE'
    },
    'finish_window': {
        'experiment_finish_label': 'experiment is finished',
        'thanks_labels': 'THANKS FOR PARTICIPATION!',
        'save_directory_label': 'saved file:\n',
        'main_menu_button': 'main menu'
    },
    'participant_window': {
        'field_hint': 'insert a number...',
        'code_field': 'participant code',
        'age_field': 'age',
        'gender_radio': 'gender',
        'hand_radio': 'leading hand',
        'back_button': 'back',
        'next_button': 'next'
    },
    'settings_window': {
        'experiment_tab': 'Experiment',
        'glove_tab': 'Glove',
        'myograph_tab': 'Myograph',
        'back_button': 'back',
        'save_button': 'save',
        'text_field_hint': 'insert text...',
        'number_field_hint': 'insert a number...',
        'save_data_dir_field': 'Directory for data saving',
        'number_of_exercise_repeats_field': 'Number of exercises repeats',
        'exercise_time_field': 'Exercise duration (s)',
        'rest_time_field': 'Rest duration (s)',
        'ip_address_field': 'Ip-address',
        'port_field': 'Port',
        'high_pass_filter': 'High pass filter',
        'low_pass_filter': 'Low pass filter',
        'detection_mode': 'Lead type',
        'electrodes_type': 'Electrodes type',
        'adapter_type': 'Adapter type',
        'sampling_rate': 'Sampling rate (Hz)',
        'active_in_channels': 'Active In channels'
    }
}

# %%
dct = {
    'rus': rus,
    'eng': eng
}

with open('../resources/labels.json', mode='w') as json_file:
    json.dump(dct, json_file)
